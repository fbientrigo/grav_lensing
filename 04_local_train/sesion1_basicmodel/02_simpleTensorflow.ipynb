# %% [markdown]
# # Training
# Este notebook inspirado en el colab anterior esta hecho para poder realizar entrenamiento simple

# %%
# !cd ../data && wget https://descargas.inf.santiago.usm.cl/train/4.tar.gz .

# %%
# !tar -xf ../data/4.tar.gz -C ../data

# %%
#!pip install scikit-optimize

# %% [markdown]
# # Codigo de Optimizacion
# Definimos los parametros a modificar para realizar proceso de optimizacion

# %%
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Integer, Categorical
from skopt.callbacks import CheckpointSaver

from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.plots import plot_histogram, plot_objective_2D

from skopt.utils import use_named_args

# guardar informacion
import pickle
import os

# %% [markdown]
# # Codigo

# %%
import datetime
import json

import matplotlib.pyplot as plt
from grav_lens import load_tf_dataset

import numpy as np
import tensorflow as tf

#data
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
# training and modeling
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D


def plot_images(images, cls_true, cls_pred=None, **kwargs):
    assert len(images) == len(cls_true) == 9
    img_shape = images[0].shape
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i].reshape(img_shape), cmap='binary')

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)

        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])

    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()



def log_dir_name(learning_rate, activation):
    """Helper function para usar tensorboard"""
    # The dir-name for the TensorBoard log-dir.
    s = "./logs/lr_{0:.0e}_act_{1}/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

    # Insert all the hyper-parameters in the dir-name.
    log_dir = s.format(learning_rate,
                       activation)

    return log_dir


def save_hyperparameters(learning_rate, activation, counter):
    hyperparameters = {
        'learning_rate': learning_rate,
        'activation': activation
    }
    
    with open(f'hyperparameters_{counter}.json', 'w') as f:
        json.dump(hyperparameters, f)
# Out:
# 2024-08-14 08:21:56.004098: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-14 08:21:56.004671: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-14 08:21:56.006738: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-14 08:21:56.012778: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-14 08:21:56.022129: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-14 08:21:56.024867: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-14 08:21:56.032053: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-14 08:21:56.488486: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

def split_dataset(X_data, Y_data, val_split=0.2, test_split=0.1):
    # Dividir los datos en entrenamiento y conjunto temporal
    X_train, X_temp, Y_train, Y_temp = train_test_split(X_data, Y_data, test_size=val_split + test_split)
    
    # Dividir los datos temporales en validación y prueba
    X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=test_split / (val_split + test_split))
    
    # Convertir a dataset de TensorFlow
    train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
    val_dataset = tf.data.Dataset.from_tensor_slices((X_val, Y_val))
    test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
    
    return train_dataset, val_dataset, test_dataset

def prepare_dataset(dataset, batch_size=32, shuffle_buffer=1000):
    dataset = dataset.shuffle(buffer_size=shuffle_buffer)  # Mezclar datos
    dataset = dataset.batch(batch_size)  # Batching
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)  # Prefetch para optimización
    return dataset

def get_datasets(data_index='4', max_files=100, home='..', batch_size=32, val_split=0.2, test_split=0.1):
    # Cargar el dataset
    dataset = load_tf_dataset(data_index=data_index, max_files=max_files, home=home)
    
    # Convertir el dataset en arrays Numpy para facilitar la división
    X_data = np.array([X.numpy() for X, _ in dataset])
    Y_data = np.array([Y.numpy() for _, Y in dataset])
    
    # Dividir el dataset en entrenamiento, validación y prueba
    train_dataset, val_dataset, test_dataset = split_dataset(X_data, Y_data, val_split, test_split)
    
    # Preparar cada dataset
    train_dataset = prepare_dataset(train_dataset, batch_size)
    val_dataset = prepare_dataset(val_dataset, batch_size)
    test_dataset = prepare_dataset(test_dataset, batch_size)
    
    return train_dataset, val_dataset, test_dataset

# Ejemplo de uso
train_dataset, val_dataset, test_dataset = get_datasets(data_index='4', max_files=100, home='..//..')

for X, Y in train_dataset.take(1):  # Mostrar un batch de entrenamiento
    print("Train X:", X.shape)
    print("Train Y:", Y.shape)

for X, Y in val_dataset.take(1):  # Mostrar un batch de validación
    print("Val X:", X.shape)
    print("Val Y:", Y.shape)

for X, Y in test_dataset.take(1):  # Mostrar un batch de prueba
    print("Test X:", X.shape)
    print("Test Y:", Y.shape)
# Out:
# Using data folder: ..//../data/4
# Train X: (32, 128, 128, 3)
# Train Y: (32, 128, 128, 1)
# Val X: (20, 128, 128, 3)
# Val Y: (20, 128, 128, 1)
# Test X: (11, 128, 128, 3)
# Test Y: (11, 128, 128, 1)
# 2024-08-14 08:22:25.849502: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
import tensorflow as tf

# Definir una pérdida personalizada que combine MAE y KL Divergence
def combined_loss(y_true, y_pred):
    mae_loss = tf.keras.losses.mae(y_true, y_pred)  # Usar la función abreviada mae()
    kl_loss = tf.keras.losses.kld(y_true, y_pred)   # Usar la función abreviada kld()
    return mae_loss + kl_loss  # Puedes ponderar las pérdidas si es necesario


def create_model(learning_rate=1e-4, activation="relu"):
    """
    Una arquitectura fija y jugamos con el learning rate
    Hyper-parameters:
        learning_rate:     Learning-rate for the optimizer.
        activation:        Activation function for hidden layers
    """
    model = tf.keras.models.Sequential([
        tf.keras.layers.Input(shape=(128, 128, 3)),  # Usar la forma original
        tf.keras.layers.Conv2D(32, (5, 5), activation=activation, padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(64, (5, 5), activation=activation, padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(128, (5, 5), activation=activation, padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(1, (5, 5), activation=activation, padding='same')  # Salida con 1 canal
    ])

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=learning_rate), loss=combined_loss)

    return model

def load_hyperparameters(counter):
    with open(f'hyperparameters_{counter}.json', 'r') as f:
        hyperparameters = json.load(f)
    return hyperparameters

def load_model_with_hyperparameters(counter):
    # Cargar los hiperparámetros
    hyperparameters = load_hyperparameters(counter)
    learning_rate = hyperparameters['learning_rate']
    activation = hyperparameters['activation']

    # Recrear el modelo con los hiperparámetros cargados
    model = create_model(learning_rate, activation)
    
    # Cargar los pesos del modelo
    model.load_weights(f'best_model_{counter}.weights.h5')

    return model

# Crear el modelo
model = load_model_with_hyperparameters(8)
model.summary()
# Out:
# /home/ftrigo/Escritorio/gravlens/venv/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 32)   │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 128, 128, 64)   │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 128, 128, 128)  │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128, 128, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 128, 128, 1)    │         3,201 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 262,721 (1.00 MB)
#  Trainable params: 262,273 (1.00 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Definiendo la forma de pasar parametros a la funcion de optimizacion
dim_learning_rate = Real(low=1e-6, high=1e-2, prior='log-uniform',
                         name='learning_rate')
#dim_num_dense_layers = Integer(low=1, high=5, name='num_dense_layers')
dim_activation = Categorical(categories=['relu', 'sigmoid', 'tanh'],
                             name='activation')


dimensions = [dim_learning_rate, dim_activation]
dimension_names = [x.name for x in dimensions]
default_parameters = [1e-5, 'relu']

# %%
import time
# Inicializar best_accuracy
best_loss = float('inf')
verbose = 1
counter = 1

# Función objetivo
@use_named_args(dimensions=dimensions)
def F_objective(learning_rate, activation):
    """
    Una arquitectura fija y jugamos con el learning rate, activacion y batchs
    Hyper-parameters:
        learning_rate:      Ratio de aprendizaje para optimizacodres
        activation:         Acticion capas internas
        batch_size:         Organizacion del batch para adtos
    """
    # Crear el modelo
    model = create_model(learning_rate, activation)
    # prepared_dataset = prepare_dataset(train_dataset, batch_size)

    log_dir = log_dir_name(learning_rate, activation)
    tensorboard_callback = TensorBoard(
        log_dir=log_dir,
        histogram_freq=0,
        write_graph=True)


    # Entrenar el modelo con TensorBoard callback
    model.fit(train_dataset, epochs=15, verbose=verbose, callbacks=[tensorboard_callback])

    loss = model.evaluate(val_dataset, verbose=0)


    # Print the classification accuracy.
    print()
    print("loss: {0:.2%}".format(loss))
    print()

    # Guardamos la mejor precision
    global best_loss, counter

    if loss < best_loss:
        # Salvar modelo
        model.save_weights(f'best_model_{counter}.weights.h5')

        # Guardar hiperparámetros
        save_hyperparameters(learning_rate, activation, counter)

        
        print(f"Model weights and hyperparameters saved with ID: {counter}")
        counter += 1
        # Update the classification accuracy.
        best_loss = loss
    
    # Borrar el modelo y los hiperparametro de memoria
    del model
    # y reiniciar el grafo computacional
    K.clear_session()
    return loss  # Queremos maximizar la precisión, por lo que minimizamos -precisión

# Comprobar funcionamiento
start_time = time.time()
F_objective(x=default_parameters)
end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Execution time: {execution_time_minutes:.2f} minutes")
# Out:
# Epoch 1/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - loss: 0.6541
# Epoch 2/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - loss: 0.6241
# Epoch 3/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - loss: 0.5979
# Epoch 4/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - loss: 0.5777
# Epoch 5/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - loss: 0.5631
# Epoch 6/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - loss: 0.5602
# Epoch 7/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - loss: 0.5499
# Epoch 8/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - loss: 0.5441
# Epoch 9/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - loss: 0.5335
# Epoch 10/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - loss: 0.5291
# Epoch 11/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - loss: 0.5233
# Epoch 12/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - loss: 0.5201
# Epoch 13/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - loss: 0.5086
# Epoch 14/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - loss: 0.5065
# Epoch 15/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - loss: 0.5034
#
# loss: 37.36%
#
# Model weights and hyperparameters saved with ID: 1
# Execution time: 11.32 minutes

# %%
model = load_model_with_hyperparameters(8)

for X, Y in test_dataset.take(1):
    prediction = model.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 2024-08-14 08:23:00.763630: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
prediction.shape
# Out:
# (11, 128, 128, 1)

# %%
# Obtener la primera imagen de la predicción
predicted_images = prediction

# Configurar la figura
fig, axes = plt.subplots(1, predicted_images.shape[0], figsize=(20, 10))
axes = axes.flatten()

# Graficar cada imagen
for img, ax in zip(predicted_images, axes):
    ax.imshow(np.squeeze(img))  # Quitar el canal de color si es necesario
    ax.axis('off')

plt.show()

# %% [markdown]
# # GRAN MINIMIZACION

# %% [markdown]
# Codigo de minimizacion
# Posiblemente tome bastante tiempo en ejecutarse

# %%
train_dataset, val_dataset, test_dataset = get_datasets(data_index='4', max_files=2000, home='..')
# Out:
# Using data folder: ../data/4

# %%
# Crear un callback para guardar checkpoints
checkpoint_saver = CheckpointSaver("checkpoint.pkl", compress=9)

# Ejecutar la optimizacion
start_time = time.time()
res = gp_minimize(func=F_objective,
                    dimensions=dimensions,
                    acq_func='EI', # Expected Improvement.
                    n_calls=50,
                    x0=default_parameters,
                    callback=[checkpoint_saver])
end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Execution time: {execution_time_minutes:.2f} minutes")
# Out:
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.6069
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5486
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.5130
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4922
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4770
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4640
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.4555
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4477
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4426
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.4349
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4264
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4219
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4150
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4090
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4047
#
# loss: 37.12%
#
# Model weights and hyperparameters saved with ID: 2
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5420
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4555
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4048
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3683
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3471
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3210
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3026
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2777
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2520
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2390
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2265
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2215
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2140
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2117
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2091
#
# loss: 20.56%
#
# Model weights and hyperparameters saved with ID: 3
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.7030
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.6585
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.6258
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5961
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.5688
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5516
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.5309
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.5136
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4990
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4845
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4711
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4596
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4505
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4468
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4390
#
# loss: 42.48%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.9295
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.9812
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.9947
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.9799
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.9570
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.9534
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.9466
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.9467
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.9528
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - loss: 0.9791
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.9582
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.9562
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.9583
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.9603
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.9573
#
# loss: 95.61%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 0.5695
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4455
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4416
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3897
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4533
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.5260
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4116
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4063
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4730
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4216
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3526
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.5289
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4215
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5407
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3922
#
# loss: 37.63%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4690
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.3677
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4098
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2641
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2434
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2438
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2137
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2329
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2139
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2107
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2073
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2046
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.1979
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1991
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2094
#
# loss: 19.74%
#
# Model weights and hyperparameters saved with ID: 4
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 0.5542
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.5844
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.6798
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4515
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3660
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4092
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4510
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4003
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.6025
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4752
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.5356
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.5444
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.7601
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5435
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3604
#
# loss: 31.49%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.6303
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.6208
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.6130
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.6075
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.6000
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.5947
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5884
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5823
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.5788
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.5749
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5693
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5668
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5623
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5592
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5563
#
# loss: 49.49%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.5498
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4475
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3926
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3600
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3423
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3487
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3063
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2921
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2794
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2581
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2540
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2499
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2392
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2411
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2263
#
# loss: 21.78%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.6098
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5979
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5870
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5781
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5680
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5568
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5485
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5414
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5327
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5280
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5226
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5160
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.5112
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5082
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5035
#
# loss: 58.85%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5506
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4461
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4190
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3895
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3851
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3532
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3254
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3175
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3048
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2819
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2687
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2650
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2444
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2398
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2393
#
# loss: 23.87%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5088
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.4132
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3358
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3040
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3184
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2485
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2465
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2355
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2394
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2214
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2120
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2080
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2022
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2009
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2050
#
# loss: 22.88%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4509
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.2528
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0638
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0427
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0407
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0404
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0396
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0399
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0395
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0396
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
#
# loss: 4.49%
#
# Model weights and hyperparameters saved with ID: 5
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 0.4196
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0719
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0408
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0400
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0403
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0399
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0389
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0385
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0384
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0378
#
# loss: 4.13%
#
# Model weights and hyperparameters saved with ID: 6
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.2920
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0452
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0408
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0402
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0385
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0370
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0361
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0353
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0370
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0547
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0436
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0433
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0386
#
# loss: 4.60%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4683
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4588
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4516
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4346
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4145
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3856
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3503
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3135
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.2780
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2410
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2106
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1844
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1649
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1513
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1425
#
# loss: 95.95%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3398
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0579
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0459
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0631
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0425
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0417
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0501
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0440
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0413
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0387
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0385
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0382
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0381
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0385
#
# loss: 22.95%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3246
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0463
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0407
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0402
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0389
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0387
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0378
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0373
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0368
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0364
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0355
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0354
#
# loss: 9.29%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4708
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4711
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4691
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4697
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4694
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4686
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4691
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4675
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4661
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4685
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4666
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4665
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4669
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4675
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4651
#
# loss: 47.53%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4410
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1615
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0435
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0407
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0404
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0400
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0397
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0392
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0391
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
#
# loss: 4.65%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.2832
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0443
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0411
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0405
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0387
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0373
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0342
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0329
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0321
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0310
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0312
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0297
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0295
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0294
#
# loss: 3.54%
#
# Model weights and hyperparameters saved with ID: 7
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4783
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3383
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2426
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2004
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2001
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2010
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2035
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2001
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1989
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1976
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2101
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2029
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1980
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1985
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2049
#
# loss: 19.75%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 0.2808
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0436
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0412
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0404
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0396
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0376
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0369
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0356
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0338
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0328
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0320
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0317
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0312
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0311
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0310
#
# loss: 3.77%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.3880
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0433
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0408
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0400
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0388
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0385
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0384
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0376
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0370
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0369
#
# loss: 4.13%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4331
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1196
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0416
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0407
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0404
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0401
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0397
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0389
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0390
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0391
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0388
#
# loss: 4.45%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4347
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1276
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0418
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0404
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0402
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0399
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0397
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0396
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0395
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0395
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0392
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0390
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0390
#
# loss: 4.46%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4360
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1390
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0427
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0402
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0403
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0402
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0399
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0391
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0390
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0391
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0387
#
# loss: 3.99%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4553
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2994
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2851
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2074
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2110
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2126
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1992
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1973
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2240
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2078
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2540
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2065
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2060
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1998
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2034
#
# loss: 19.75%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4336
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1220
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0418
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0404
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0404
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0398
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0388
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0390
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0387
#
# loss: 4.17%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4361
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1258
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0417
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0406
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0401
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0400
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0398
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0397
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0389
#
# loss: 4.11%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.5247
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.4029
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2708
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2233
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2357
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2011
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2025
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2347
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2077
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2133
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.1998
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.1993
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1986
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2013
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2149
#
# loss: 19.96%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4944
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3840
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2416
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2269
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2298
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2088
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2047
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.1994
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2023
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2016
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2004
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1976
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2012
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1972
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1973
#
# loss: 19.56%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4782
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2999
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2477
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2460
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2075
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2000
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2025
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2050
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2018
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2002
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1983
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2013
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1987
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1993
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1979
#
# loss: 19.49%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4786
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3099
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3235
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2141
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2136
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2040
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.1981
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1989
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1990
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2166
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2039
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2087
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2021
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2040
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2025
#
# loss: 19.41%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4601
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3702
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1861
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0752
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0483
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0430
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0408
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0408
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0401
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0403
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0402
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0401
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0399
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0395
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0398
#
# loss: 4.38%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.2882
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0444
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0414
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0407
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0400
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0391
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0384
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0368
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0351
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0344
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0334
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0321
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0318
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0311
#
# loss: 3.92%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.2797
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0445
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0412
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0401
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0390
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0375
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0345
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0331
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0326
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0319
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0314
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0306
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0299
#
# loss: 3.44%
#
# Model weights and hyperparameters saved with ID: 8
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4435
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1887
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0464
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0411
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0403
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0400
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0399
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0396
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0397
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0395
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0392
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0390
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0391
#
# loss: 4.56%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4427
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1858
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0469
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0410
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0405
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0401
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0396
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0397
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0389
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
#
# loss: 4.55%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 0.4451
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1946
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0469
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0408
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0403
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0399
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0404
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0395
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0398
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0390
#
# loss: 4.60%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4444
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1899
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0463
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0411
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0404
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0399
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0396
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
#
# loss: 4.38%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4438
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1924
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0472
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0411
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0401
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0402
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0398
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0390
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0390
#
# loss: 4.70%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4437
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1934
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0480
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0409
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0404
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0402
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0402
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0399
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0398
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0399
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0395
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0395
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0391
#
# loss: 4.20%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4433
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1886
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0475
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0413
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0405
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0402
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0396
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0399
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0399
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0392
#
# loss: 4.40%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 0.4446
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1946
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0475
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0406
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0408
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0401
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0401
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0394
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0395
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0392
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
#
# loss: 4.82%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4441
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1946
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0477
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0410
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0404
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0399
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0396
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0396
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0391
#
# loss: 4.74%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 0.4466
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1993
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0483
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0413
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0404
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0402
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0396
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0398
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0396
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
#
# loss: 4.44%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.4772
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.3714
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2797
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3495
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2310
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2767
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2161
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2042
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2017
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2069
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2039
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2093
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1994
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2028
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2029
#
# loss: 19.58%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4451
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.1935
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0472
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0408
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0404
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0401
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0399
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0396
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0396
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0397
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0393
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0393
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0395
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.0394
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.0391
#
# loss: 4.77%
#
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 0.4830
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.3451
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2566
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2634
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2614
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2125
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2088
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2010
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1969
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1924
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2003
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2017
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 0.2004
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.1967
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 0.2030
#
# loss: 19.46%
#
# Execution time: 1098.34 minutes

# %%
# Guardar el objeto res, para hacer estadistica despues
with open('optimization_results.pkl', 'wb') as f:
    pickle.dump(res, f)

# %% [markdown]
# # Hacer un plot
# Veamos que tal lo ha hecho el modelo

# %%
plot_convergence(res)
print(res.space)
print(res.x)
print("Accuracy: ", res.fun)
# Out:
# Space([Real(low=1e-06, high=0.01, prior='log-uniform', transform='normalize'),
#        Categorical(categories=('relu', 'sigmoid', 'tanh'), prior=None)])
# [0.003636525599163243, 'sigmoid']
# Accuracy:  -0.03442706912755966

# %%
from skopt.plots import plot_histogram, plot_objective_2D

plot_histogram(result=res,  dimension_identifier='activation')
plt.show()

# %%
plot_objective(result=res, dimensions=dimension_names)
# Out:
# <Axes: >

# %%
plot_evaluations(result=res, dimensions=dimension_names)
# Out:
# <Axes: >
